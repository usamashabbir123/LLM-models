# %%
# imports
import ollama
import os
from dotenv import load_dotenv
# load display and markdown for jupyter notebook
from IPython.display import display, Markdown,update_display

from openai import OpenAI

# %%
ollama_model='llama3.2:latest'

# %%
# here is the question; type over this to ask something new

question = """
Please explain what this code does and why:
yield from {book.get("author") for book in books if book.get("author")}
"""
system_prompt = """You are a helpful programming assistant. Provide concise explanations. Use bullet points where appropriate. Be clear and to the point. If you are unsure, say 'I don't know'.
Respond in markdown format. provide examples where appropriate.
"""

def get_messages(question: str, system_prompt: str) -> list[dict]:
    messages = [
        {"role": "system", "content": system_prompt},
        {"role": "user", "content": question}
    ]
    return messages

# %%
ollama_via_openai = OpenAI(base_url='http://localhost:11434/v1', api_key='ollama')

stream = ollama_via_openai.chat.completions.create(
    model='llama3.2:latest',
    messages=get_messages(question, system_prompt  
    ),
    stream=True,
)

response = ""
display_handle = display(Markdown(""), display_id=True)
for chunk in stream:
    response += chunk.choices[0].delta.content or ''
    response = response.replace("```","").replace("markdown", "")
    update_display(Markdown(response), display_id=display_handle.display_id)
# Out:
# **Code Breakdown**
#
# The given code uses a combination of Python's `yield` keyword, generator expressions, and dictionary methods.
#
# ### Code Explanation
#
# python
# yield from {
#     book.get("author")
#     for book in books
#     if book.get("author")
# }
#
#
# *   This is a generator expression that yields values.
# *   The outer `for` loop iterates over the `books` collection (assuming it's an iterable).
# *   The inner list comprehension (within curly braces `{}`) applies two conditions to each item in `books`:
#     *   It checks if the book has a key called "author" using `book.get("author")`.
#     *   If the condition is true, it yields the author's name.
#
# ### How it Works
#
# When you run this generator expression, it will produce a sequence of values (the authors' names) without storing them all in memory at once. This is particularly useful when dealing with large datasets where memory usage is limited.
#
# **Example Use Case**
#
# Suppose you have a list of books and their details stored in a nested dictionary format:
# python
# books = [
#     {"title": "Book 1", "author": "Author A"},
#     {"title": "Book 2", "author": None},  # Some books don't have authors
#     {"title": "Book 3", "author": "Author C"}
# ]
#
# The generator expression `yield from {book.get("author") for book in books if book.get("author")}` will yield:
#
# python
# ['Author A', 'Author C']
#
#
# **Advantages**
#
# This approach has several benefits, including:
# *   Memory efficiency (only one author's name is stored at a time).
# *   Flexibility (can be used with any iterable data source).
# *   Readability (generator expressions can simplify code and improve comprehension).
#
# However, the exact advantages will depend on your specific use case.
